# %%
# !pip install rdkit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: rdkit in /home/runai-home/.local/lib/python3.10/site-packages (2024.3.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.22.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.2.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
from utils import load_data

df_bindingDB = load_data()

df_bindingDB.head()
# Out:
# /mloscratch/homes/mdupont/other/ada/ada-2024-project-laambada/utils.py:11: DtypeWarning: Columns (8,9,10,11,12,13,15,17,20,21,22,23,27,28,32,33,35,36,45,46,47,48,50,51,52,53,54,55,57,58,59,60,62,63,64,65,66,67,69,70,71,72,74,75,76,77,78,79,81,82,83,86,87,88,89,90,91,93,94,95,98,99,100,101,102,103,105,106,107,110,111,112,113,114,115,117,118,119,122,123,124,125,126,127,129,130,131,134,135,136,137,138,139,146,147,148,149,150,151,158,159,160,161,162,163,170,172,173,174,175) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', on_bad_lines='skip')
#    BindingDB Reactant_set_id  \
# 0                          1
# 1                          2
# 2                          3
# 3                          4
# 4                          5
#
#                                        Ligand SMILES  \
# 0  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CCCCCC(O)=...
# 1  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(C\C=C\c2cn...
# 2  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CC2CC2)C(=...
# 3  OCCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@...
# 4  OCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@H...
#
#                                         Ligand InChI  \
# 0  InChI=1S/C31H42N2O7/c34-27(35)17-9-3-11-19-32-...
# 1  InChI=1S/C31H34N6O3/c38-29-27(17-23-9-3-1-4-10...
# 2  InChI=1S/C29H34N4O3/c34-27-25(16-21-8-3-1-4-9-...
# 3  InChI=1S/C29H40N2O4/c32-18-10-2-1-9-17-30-25(1...
# 4  InChI=1S/C28H38N2O4/c31-17-9-3-8-16-29-24(18-2...
#
#               Ligand InChI Key  BindingDB MonomerID  \
# 0  XGEGDSLAQZJGCW-HHGOQMMWSA-N               608734
# 1  UZLMEAPBHYEHAC-UNTBESQGSA-N                   22
# 2  HYNYUFZPPJMPOB-UTWJFGBXSA-N                   23
# 3  YXVAZXDWVZTGGD-VIJSPRBVSA-N                   24
# 4  WWTSWTPNILRSJX-XDZXDJIYSA-N                   25
#
#                                BindingDB Ligand Name  \
# 0  6-[(4R,5S,6S,7R)-4,7-dibenzyl-3-(5-carboxypent...
# 1  (4R,5S,6S,7R)-4,7-dibenzyl-5,6-dihydroxy-1,3-b...
# 2  (4R,5S,6S,7R)-4,7-dibenzyl-1-(cyclopropylmethy...
# 3  (4R,5S,6S,7R)-4,7-dibenzyl-1-(cyclopropylmethy...
# 4  (4R,5S,6S,7R)-4,7-dibenzyl-1-(cyclopropylmethy...
#
#                               Target Name  \
# 0  Dimer of Gag-Pol polyprotein [501-599]
# 1  Dimer of Gag-Pol polyprotein [501-599]
# 2  Dimer of Gag-Pol polyprotein [501-599]
# 3  Dimer of Gag-Pol polyprotein [501-599]
# 4  Dimer of Gag-Pol polyprotein [501-599]
#
#   Target Source Organism According to Curator or DataSource Ki (nM) IC50 (nM)  \
# 0                     Human immunodeficiency virus 1           0.24       NaN
# 1                     Human immunodeficiency virus 1           0.25       NaN
# 2                     Human immunodeficiency virus 1           0.41       NaN
# 3                     Human immunodeficiency virus 1            0.8       NaN
# 4                     Human immunodeficiency virus 1           0.99       NaN
#
#    ... UniProt (SwissProt) Recommended Name of Target Chain.12  \
# 0  ...                                                NaN
# 1  ...                                                NaN
# 2  ...                                                NaN
# 3  ...                                                NaN
# 4  ...                                                NaN
#
#   UniProt (SwissProt) Entry Name of Target Chain.12  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   UniProt (SwissProt) Primary ID of Target Chain.12  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   UniProt (SwissProt) Secondary ID(s) of Target Chain.12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    UniProt (SwissProt) Alternative ID(s) of Target Chain.12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   UniProt (TrEMBL) Submitted Name of Target Chain.12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   UniProt (TrEMBL) Entry Name of Target Chain.12  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   UniProt (TrEMBL) Primary ID of Target Chain.12  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   UniProt (TrEMBL) Secondary ID(s) of Target Chain.12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    UniProt (TrEMBL) Alternative ID(s) of Target Chain.12
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 194 columns]

# %% [markdown]
# # 1. Select a subset of ligands

# %%
df_subset = df_bindingDB.loc[100: 100040].copy()

df_subset.head()
# Out:
#      BindingDB Reactant_set_id  \
# 100                        101
# 101                        102
# 102                        103
# 103                        104
# 104                        105
#
#                                          Ligand SMILES  \
# 100  COCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@H](...
# 101  CN(C)CCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C...
# 102  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CCC23CC4CC...
# 103  O[C@@H](CCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)...
# 104  CCOCCN1[C@@H](Cc2ccccc2)[C@@H](O)[C@H](O)[C@H]...
#
#                                           Ligand InChI  \
# 100  InChI=1S/C25H34N2O5/c1-31-15-13-26-21(17-19-9-...
# 101  InChI=1S/C31H48N4O3/c1-32(2)19-11-13-21-34-27(...
# 102  InChI=1S/C43H58N2O3/c46-39-37(21-29-7-3-1-4-8-...
# 103  InChI=1S/C39H44F2N2O5/c40-31-19-15-29(16-20-31...
# 104  InChI=1S/C27H38N2O5/c1-3-33-17-15-28-23(19-21-...
#
#                 Ligand InChI Key  BindingDB MonomerID  \
# 100  MFPWTYXTECUSIK-LWSSLDFYSA-N                  121
# 101  OJXDVNXJVASQNH-XAZDILKDSA-N                  122
# 102  YYENRTDDXNTDMK-LSHQIPOWSA-N                  123
# 103  UHZHRHOHEJRMEP-BKXLAGIUSA-N                  124
# 104  MPOLZPRZMBTQLP-QEGGNFSNSA-N                  125
#
#                                  BindingDB Ligand Name  \
# 100  (4R,5S,6S,7R)-4,7-dibenzyl-5,6-dihydroxy-1,3-b...
# 101  (4R,5S,6S,7R)-4,7-dibenzyl-1,3-bis[4-(dimethyl...
# 102  (4R,5S,6S,7R)-1,3-bis[2-(adamantan-1-yl)ethyl]...
# 103  (4R,5S,6S,7R)-4,7-dibenzyl-1-[(4R)-4-(4-fluoro...
# 104  (4S,5R,6R,7S)-4,7-dibenzyl-1,3-bis(2-ethoxyeth...
#
#                                 Target Name  \
# 100  Dimer of Gag-Pol polyprotein [501-599]
# 101  Dimer of Gag-Pol polyprotein [501-599]
# 102  Dimer of Gag-Pol polyprotein [501-599]
# 103  Dimer of Gag-Pol polyprotein [501-599]
# 104  Dimer of Gag-Pol polyprotein [501-599]
#
#     Target Source Organism According to Curator or DataSource Ki (nM)  \
# 100                     Human immunodeficiency virus 1            800
# 101                     Human immunodeficiency virus 1            820
# 102                     Human immunodeficiency virus 1            903
# 103                     Human immunodeficiency virus 1            930
# 104                     Human immunodeficiency virus 1           1100
#
#     IC50 (nM)  ... UniProt (SwissProt) Recommended Name of Target Chain.12  \
# 100       NaN  ...                                                NaN
# 101       NaN  ...                                                NaN
# 102       NaN  ...                                                NaN
# 103       NaN  ...                                                NaN
# 104       NaN  ...                                                NaN
#
#     UniProt (SwissProt) Entry Name of Target Chain.12  \
# 100                                               NaN
# 101                                               NaN
# 102                                               NaN
# 103                                               NaN
# 104                                               NaN
#
#     UniProt (SwissProt) Primary ID of Target Chain.12  \
# 100                                               NaN
# 101                                               NaN
# 102                                               NaN
# 103                                               NaN
# 104                                               NaN
#
#     UniProt (SwissProt) Secondary ID(s) of Target Chain.12  \
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
#
#      UniProt (SwissProt) Alternative ID(s) of Target Chain.12  \
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
#
#     UniProt (TrEMBL) Submitted Name of Target Chain.12  \
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
#
#     UniProt (TrEMBL) Entry Name of Target Chain.12  \
# 100                                            NaN
# 101                                            NaN
# 102                                            NaN
# 103                                            NaN
# 104                                            NaN
#
#     UniProt (TrEMBL) Primary ID of Target Chain.12  \
# 100                                            NaN
# 101                                            NaN
# 102                                            NaN
# 103                                            NaN
# 104                                            NaN
#
#     UniProt (TrEMBL) Secondary ID(s) of Target Chain.12  \
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
#
#      UniProt (TrEMBL) Alternative ID(s) of Target Chain.12
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
#
# [5 rows x 194 columns]

# %% [markdown]
# # 2. Rdkit and data cleaning
# The ligands will be analyzed through rdkit, as it was showcased in the data exploration. The SMILE ligands need to be converted to rdkit molecules, and the molecules will be cleaned when not possible to convert.

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors 

sample_molecule = Chem.MolFromSmiles(df_subset["Ligand SMILES"].iloc[0])

print("Molecular weight of the first molecule: ", Descriptors.MolWt(sample_molecule))
print("Number of valence electrons of the first molecule: ", Descriptors.NumValenceElectrons(sample_molecule))
Chem.Descriptors.CalcMolDescriptors(sample_molecule, missingVal=None, silent=True)
# Out:
# Molecular weight of the first molecule:  442.5560000000003
# Number of valence electrons of the first molecule:  174
# {'MaxAbsEStateIndex': 13.768109095490047,
#  'MaxEStateIndex': 13.768109095490047,
#  'MinAbsEStateIndex': 0.22540532879818564,
#  'MinEStateIndex': -1.1136394557823135,
#  'qed': 0.5879309171190104,
#  'SPS': 23.9375,
#  'MolWt': 442.5560000000003,
#  'HeavyAtomMolWt': 408.2840000000002,
#  'ExactMolWt': 442.24677218799997,
#  'NumValenceElectrons': 174,
#  'NumRadicalElectrons': 0,
#  'MaxPartialCharge': 0.32037211047159864,
#  'MinPartialCharge': -0.3881707599697216,
#  'MaxAbsPartialCharge': 0.3881707599697216,
#  'MinAbsPartialCharge': 0.32037211047159864,
#  'FpDensityMorgan1': 0.71875,
#  'FpDensityMorgan2': 1.09375,
#  'FpDensityMorgan3': 1.4375,
#  'BCUT2D_MWHI': 16.46555143542942,
#  'BCUT2D_MWLOW': 9.908609888363157,
#  'BCUT2D_CHGHI': 2.454937597337904,
#  'BCUT2D_CHGLO': -2.350051412825495,
#  'BCUT2D_LOGPHI': 2.26784487219309,
#  'BCUT2D_LOGPLOW': -2.5230527797710303,
#  'BCUT2D_MRHI': 5.7581836802704425,
#  'BCUT2D_MRLOW': -0.041914980719869245,
#  'AvgIpc': 2.882665522785858,
#  'BalabanJ': 1.9734492627420277,
#  'BertzCT': 752.096682593248,
#  'Chi0': 22.924074484064487,
#  'Chi0n': 18.839143709165473,
#  'Chi0v': 18.839143709165473,
#  'Chi1': 15.562080607913938,
#  'Chi1n': 11.055406249031753,
#  'Chi1v': 11.055406249031753,
#  'Chi2n': 8.150287041114264,
#  'Chi2v': 8.150287041114264,
#  'Chi3n': 6.078381685114956,
#  'Chi3v': 6.078381685114956,
#  'Chi4n': 4.3478870426667084,
#  'Chi4v': 4.3478870426667084,
#  'HallKierAlpha': -2.4499999999999997,
#  'Ipc': 16296054.12017119,
#  'Kappa1': 24.19752700540736,
#  'Kappa2': 11.968788430283858,
#  'Kappa3': 5.863541429995902,
#  'LabuteASA': 189.72366106304398,
#  'PEOE_VSA1': 29.486600158982466,
#  'PEOE_VSA10': 12.207932775496605,
#  'PEOE_VSA11': 0.0,
#  'PEOE_VSA12': 0.0,
#  'PEOE_VSA13': 0.0,
#  'PEOE_VSA14': 6.031114512338072,
#  'PEOE_VSA2': 0.0,
#  'PEOE_VSA3': 4.794537184071822,
#  'PEOE_VSA4': 0.0,
#  'PEOE_VSA5': 0.0,
#  'PEOE_VSA6': 60.6636706846161,
#  'PEOE_VSA7': 23.96854622924601,
#  'PEOE_VSA8': 27.30910789438022,
#  'PEOE_VSA9': 25.297445587321757,
#  'SMR_VSA1': 24.48131788135333,
#  'SMR_VSA10': 6.031114512338072,
#  'SMR_VSA2': 0.0,
#  'SMR_VSA3': 9.799819461700956,
#  'SMR_VSA4': 0.0,
#  'SMR_VSA5': 37.133257679644544,
#  'SMR_VSA6': 40.52287182340605,
#  'SMR_VSA7': 71.7905736680101,
#  'SMR_VSA8': 0.0,
#  'SMR_VSA9': 0.0,
#  'SlogP_VSA1': 0.0,
#  'SlogP_VSA10': 4.794537184071822,
#  'SlogP_VSA11': 0.0,
#  'SlogP_VSA12': 0.0,
#  'SlogP_VSA2': 90.85847502091903,
#  'SlogP_VSA3': 22.315369153452117,
#  'SlogP_VSA4': 0.0,
#  'SlogP_VSA5': 11.126902983393991,
#  'SlogP_VSA6': 60.6636706846161,
#  'SlogP_VSA7': 0.0,
#  'SlogP_VSA8': 0.0,
#  'SlogP_VSA9': 0.0,
#  'TPSA': 82.47,
#  'EState_VSA1': 24.291614433792528,
#  'EState_VSA10': 15.007591973753232,
#  'EState_VSA11': 0.0,
#  'EState_VSA2': 6.031114512338072,
#  'EState_VSA3': 39.144919986703,
#  'EState_VSA4': 11.126902983393991,
#  'EState_VSA5': 0.0,
#  'EState_VSA6': 24.019414544256023,
#  'EState_VSA7': 60.6636706846161,
#  'EState_VSA8': 0.0,
#  'EState_VSA9': 9.473725907600098,
#  'VSA_EState1': 10.503994005800463,
#  'VSA_EState10': 0.0,
#  'VSA_EState2': 17.055886873267823,
#  'VSA_EState3': 22.630635078105314,
#  'VSA_EState4': 1.9794772880838902,
#  'VSA_EState5': 0.0,
#  'VSA_EState6': 18.047687317325664,
#  'VSA_EState7': -1.3568509070294792,
#  'VSA_EState8': 1.3044986702210726,
#  'VSA_EState9': 3.168005007558579,
#  'FractionCSP3': 0.48,
#  'HeavyAtomCount': 32,
#  'NHOHCount': 2,
#  'NOCount': 7,
#  'NumAliphaticCarbocycles': 0,
#  'NumAliphaticHeterocycles': 1,
#  'NumAliphaticRings': 1,
#  'NumAromaticCarbocycles': 2,
#  'NumAromaticHeterocycles': 0,
#  'NumAromaticRings': 2,
#  'NumHAcceptors': 5,
#  'NumHDonors': 2,
#  'NumHeteroatoms': 7,
#  'NumRotatableBonds': 10,
#  'NumSaturatedCarbocycles': 0,
#  'NumSaturatedHeterocycles': 1,
#  'NumSaturatedRings': 1,
#  'RingCount': 3,
#  'MolLogP': 1.9612,
#  'MolMR': 122.44160000000007,
#  'fr_Al_COO': 0,
#  'fr_Al_OH': 2,
#  'fr_Al_OH_noTert': 2,
#  'fr_ArN': 0,
#  'fr_Ar_COO': 0,
#  'fr_Ar_N': 0,
#  'fr_Ar_NH': 0,
#  'fr_Ar_OH': 0,
#  'fr_COO': 0,
#  'fr_COO2': 0,
#  'fr_C_O': 1,
#  'fr_C_O_noCOO': 1,
#  'fr_C_S': 0,
#  'fr_HOCCN': 0,
#  'fr_Imine': 0,
#  'fr_NH0': 2,
#  'fr_NH1': 0,
#  'fr_NH2': 0,
#  'fr_N_O': 0,
#  'fr_Ndealkylation1': 0,
#  'fr_Ndealkylation2': 0,
#  'fr_Nhpyrrole': 0,
#  'fr_SH': 0,
#  'fr_aldehyde': 0,
#  'fr_alkyl_carbamate': 0,
#  'fr_alkyl_halide': 0,
#  'fr_allylic_oxid': 0,
#  'fr_amide': 2,
#  'fr_amidine': 0,
#  'fr_aniline': 0,
#  'fr_aryl_methyl': 0,
#  'fr_azide': 0,
#  'fr_azo': 0,
#  'fr_barbitur': 0,
#  'fr_benzene': 2,
#  'fr_benzodiazepine': 0,
#  'fr_bicyclic': 0,
#  'fr_diazo': 0,
#  'fr_dihydropyridine': 0,
#  'fr_epoxide': 0,
#  'fr_ester': 0,
#  'fr_ether': 2,
#  'fr_furan': 0,
#  'fr_guanido': 0,
#  'fr_halogen': 0,
#  'fr_hdrzine': 0,
#  'fr_hdrzone': 0,
#  'fr_imidazole': 0,
#  'fr_imide': 0,
#  'fr_isocyan': 0,
#  'fr_isothiocyan': 0,
#  'fr_ketone': 0,
#  'fr_ketone_Topliss': 0,
#  'fr_lactam': 0,
#  'fr_lactone': 0,
#  'fr_methoxy': 2,
#  'fr_morpholine': 0,
#  'fr_nitrile': 0,
#  'fr_nitro': 0,
#  'fr_nitro_arom': 0,
#  'fr_nitro_arom_nonortho': 0,
#  'fr_nitroso': 0,
#  'fr_oxazole': 0,
#  'fr_oxime': 0,
#  'fr_para_hydroxylation': 0,
#  'fr_phenol': 0,
#  'fr_phenol_noOrthoHbond': 0,
#  'fr_phos_acid': 0,
#  'fr_phos_ester': 0,
#  'fr_piperdine': 0,
#  'fr_piperzine': 0,
#  'fr_priamide': 0,
#  'fr_prisulfonamd': 0,
#  'fr_pyridine': 0,
#  'fr_quatN': 0,
#  'fr_sulfide': 0,
#  'fr_sulfonamd': 0,
#  'fr_sulfone': 0,
#  'fr_term_acetylene': 0,
#  'fr_tetrazole': 0,
#  'fr_thiazole': 0,
#  'fr_thiocyan': 0,
#  'fr_thiophene': 0,
#  'fr_unbrch_alkane': 0,
#  'fr_urea': 1}

# %%
import time
import numpy as np

# Liste pour stocker les temps d'exécution
execution_times = []

smiles_to_molecules = []
for smiles in df_subset['Ligand SMILES']:
    start_time = time.time()
    molecule = Chem.MolFromSmiles(smiles) 
    smiles_to_molecules.append(molecule)
    end_time = time.time()
    execution_times.append(end_time - start_time)

# Calculer les statistiques
mean_time = np.mean(execution_times)
std_time = np.std(execution_times)

print(f"Mean execution time: {mean_time} seconds")
print(f"Standard deviation: {std_time} seconds")
print(f"Estimation for the full dataset: {round(len(df_bindingDB)*mean_time/60)} minutes")

df_subset['RDKIT Molecules'] = smiles_to_molecules
# Out:
# [21:03:52] non-ring atom 28 marked aromatic
# [21:03:52] non-ring atom 28 marked aromatic
# [21:03:52] Explicit valence for atom # 28 N, 4, is greater than permitted
# [21:03:56] Explicit valence for atom # 12 N, 4, is greater than permitted
# [21:03:56] Explicit valence for atom # 12 N, 4, is greater than permitted
# [21:04:02] Explicit valence for atom # 17 O, 3, is greater than permitted
# [21:04:02] Explicit valence for atom # 16 O, 3, is greater than permitted
# [21:04:02] Explicit valence for atom # 16 O, 3, is greater than permitted
# [21:04:02] Explicit valence for atom # 17 O, 3, is greater than permitted
# [21:04:02] Explicit valence for atom # 16 O, 3, is greater than permitted
# [21:04:02] Explicit valence for atom # 16 O, 3, is greater than permitted
# Mean execution time: 0.0001906818816398489 seconds
# Standard deviation: 0.000254280433917335 seconds
# Estimation for the full dataset: 9 minutes

# %%
print(f"Number of molecules not processed by rdkit: {df_subset['RDKIT Molecules'].isna().sum()} out of {len(df_subset)} ligands")
# Delete these rows
df_subset = df_subset.dropna(subset=['RDKIT Molecules'])
print(len(df_subset))
# Out:
# Number of molecules not processed by rdkit: 11 out of 99941 ligands
# 99930

# %% [markdown]
# # 3. Univariate data analysis
# The univariate data analysis will be performed on the ligands. The analysis will be performed on features that we need to calculate from rdkit.

# %% [markdown]
# ## 3.1. Molecular weight

# %%
# 1. Molecular weight
molecular_weights = []

for molecule in df_subset['RDKIT Molecules']:
    start_time = time.time()
    mw = Descriptors.MolWt(molecule)   
    molecular_weights.append(mw) 
    end_time = time.time()
    execution_times.append(end_time - start_time)

# Calculer les statistiques
mean_time = np.mean(execution_times)
std_time = np.std(execution_times)

print(f"Mean execution time: {mean_time} seconds")
print(f"Standard deviation: {std_time} seconds")
print(f"Estimation for the full dataset: {round(len(df_bindingDB)*mean_time/60)} minutes")
# Out:
# Mean execution time: 9.855586666021654e-05 seconds
# Standard deviation: 0.00020205370029016868 seconds
# Estimation for the full dataset: 5 minutes

# %%
import matplotlib.pyplot as plt
import pandas as pd
molecular_weights = pd.Series(molecular_weights)

plt.figure(figsize=(10, 6))
molecular_weights.plot(kind = 'hist')
plt.xlabel('Molecular weight')
plt.ylabel('Frequency')
plt.title('Molecular weight of ligands')
plt.show()

# %% [markdown]
# ## 3.2 Functionnal group counts

# %%
from rdkit.Chem import Fragments

# Example SMILES list from your DataFrame
smiles_list = df_subset['Ligand SMILES']  # Assuming ligands_subset is a DataFrame

# Calculate functional group counts for each molecule
results = []
for smiles in smiles_list:
    molecule = Chem.MolFromSmiles(smiles)
    if molecule:
        counts = {
            "SMILES": smiles,
            "Aliphatic OH": Fragments.fr_Al_OH(molecule),
            "Aromatic NH": Fragments.fr_Ar_NH(molecule),
            "Ester": Fragments.fr_ester(molecule),
            "Ether": Fragments.fr_ether(molecule),
            "Amide": Fragments.fr_amide(molecule),
            "Ketone": Fragments.fr_ketone(molecule),
            "Benzene Ring": Fragments.fr_benzene(molecule),
            # Add additional groups as desired
        }
        results.append(counts)

# %%
# Convert results to DataFrame
df_results = pd.DataFrame(results)
df_results.set_index('SMILES', inplace=True)
df_results.head()
# Out:
#                                                     Aliphatic OH  Aromatic NH  \
# SMILES
# COCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@H](C...             2            0
# CN(C)CCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@...             2            0
# O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CCC23CC4CC(...             2            0
# O[C@@H](CCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[...             4            0
# CCOCCN1[C@@H](Cc2ccccc2)[C@@H](O)[C@H](O)[C@H](...             2            0
#
#                                                     Ester  Ether  Amide  \
# SMILES
# COCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@H](C...      0      2      2
# CN(C)CCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@...      0      0      2
# O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CCC23CC4CC(...      0      0      2
# O[C@@H](CCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[...      0      0      2
# CCOCCN1[C@@H](Cc2ccccc2)[C@@H](O)[C@H](O)[C@H](...      0      2      2
#
#                                                     Ketone  Benzene Ring
# SMILES
# COCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@H](C...       0             2
# CN(C)CCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@...       0             2
# O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CCC23CC4CC(...       0             2
# O[C@@H](CCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[...       0             4
# CCOCCN1[C@@H](Cc2ccccc2)[C@@H](O)[C@H](O)[C@H](...       0             2

# %%
import matplotlib.pyplot as plt
column_means = df_results.mean()

plt.figure(figsize=(10, 6))
column_means.plot(kind='bar')
plt.xlabel('Features')
plt.ylabel('Mean Value')
plt.title('Mean of functionnal group counts')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 3.3 Hydrophobicity

# %%
df_subset['logP'] = [Descriptors.MolLogP(molecule) for molecule in df_subset['RDKIT Molecules']]

# %%
plt.figure(figsize=(10, 6))
df_subset['logP'].plot(kind='hist')
plt.xlabel('logP')
plt.ylabel('Frequency')
plt.title('logP distribution')
plt.show()

# %% [markdown]
# ## 3.4 Charge

# %%
df_subset['Charge'] = [Chem.GetFormalCharge(molecule) for molecule in df_subset['RDKIT Molecules']]

# %%
plt.figure(figsize=(10, 6))
df_subset['Charge'].plot(kind='hist', logy=True)
plt.xlabel('Charge')
plt.ylabel('Frequency')
plt.title('Ligand charge')
plt.show()
